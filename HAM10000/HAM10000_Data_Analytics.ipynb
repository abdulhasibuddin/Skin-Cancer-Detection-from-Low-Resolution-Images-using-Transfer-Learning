# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
readfile_dir = "drive/My Drive/HAM10000/"
filename = "HAM10000_metadata.csv"

# %%
df_dataset = pd.read_csv(readfile_dir+filename) #, header = None

# %%
df_dataset
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
df_dataset['dx'].value_counts()
# Out:
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: dx, dtype: int64

# %%
hist_dx = df_dataset['dx'].hist()

# %%
df_dataset['sex'].value_counts()
# Out:
# male       5406
# female     4552
# unknown      57
# Name: sex, dtype: int64

# %%
df_dataset['age'].value_counts()
# Out:
# 45.0    1299
# 50.0    1187
# 55.0    1009
# 40.0     985
# 60.0     803
# 70.0     756
# 35.0     753
# 65.0     731
# 75.0     618
# 30.0     464
# 80.0     404
# 85.0     290
# 25.0     247
# 20.0     169
# 5.0       86
# 15.0      77
# 10.0      41
# 0.0       39
# Name: age, dtype: int64

# %%
hist_age = df_dataset['age'].hist()

# %%
df_dataset['dx_type'].value_counts()
# Out:
# histo        5340
# follow_up    3704
# consensus     902
# confocal       69
# Name: dx_type, dtype: int64

# %%
df_dataset['localization'].value_counts()
# Out:
# back               2192
# lower extremity    2077
# trunk              1404
# upper extremity    1118
# abdomen            1022
# face                745
# chest               407
# foot                319
# unknown             234
# neck                168
# scalp               128
# hand                 90
# ear                  56
# genital              48
# acral                 7
# Name: localization, dtype: int64

# %%
df_nv = df_dataset[['lesion_id','image_id']].loc[df_dataset['dx'] == 'nv']
df_nv.shape
# Out:
# (6705, 2)

# %%
df_nv.to_csv(readfile_dir+"HAM10000_image_indices_nv.csv", mode='w')

# %%
df_mel = df_dataset[['lesion_id','image_id']].loc[df_dataset['dx'] == 'mel']
df_mel.shape
# Out:
# (1113, 2)

# %%
df_mel.to_csv(readfile_dir+"HAM10000_image_indices_mel.csv", mode='w')

# %%
df_bkl = df_dataset[['lesion_id','image_id']].loc[df_dataset['dx'] == 'bkl']
df_bkl.shape
# Out:
# (1099, 2)

# %%
df_bkl.to_csv(readfile_dir+"HAM10000_image_indices_bkl.csv", mode='w')

# %%
df_bcc = df_dataset[['lesion_id','image_id']].loc[df_dataset['dx'] == 'bcc']
df_bcc.shape
# Out:
# (514, 2)

# %%
df_bcc.to_csv(readfile_dir+"HAM10000_image_indices_bcc.csv", mode='w')

# %%
df_akiec = df_dataset[['lesion_id','image_id']].loc[df_dataset['dx'] == 'akiec']
df_akiec.shape
# Out:
# (327, 2)

# %%
df_akiec.to_csv(readfile_dir+"HAM10000_image_indices_akiec.csv", mode='w')

# %%
df_vasc = df_dataset[['lesion_id','image_id']].loc[df_dataset['dx'] == 'vasc']
df_vasc.shape
# Out:
# (142, 2)

# %%
df_vasc.to_csv(readfile_dir+"HAM10000_image_indices_vasc.csv", mode='w')

# %%
df_df = df_dataset[['lesion_id','image_id']].loc[df_dataset['dx'] == 'df']
df_df.shape
# Out:
# (115, 2)

# %%
df_df.to_csv(readfile_dir+"HAM10000_image_indices_df.csv", mode='w')
